# %% [markdown]
# # Red30 Tech Datasets

# %% [markdown]
# This notebook focuses on the course dataset: Red30 Tech US online retail sales.
#
# Let's start by import the pandas and duckdb libraries:

# %%
import pandas as pd
import duckdb as db

# %% [markdown]
# Next, we will load the dataset from a CSV file from the `data` folder:

# %%
retail_sales = pd.read_csv("../data/Red30 Tech US online retail sales.csv")

# %% [markdown]
# Let's take a look at the table header:

# %%
retail_sales.head(10)
# Out:
#    OrderNum OrderDate  OrderType CustomerType                CustName  \
# 0   1100934  9/1/2017  Wholesale     Business        Gusikowski Group
# 1   1100935  9/1/2017     Retail   Individual       Spencer Educators
# 2   1100936  9/1/2017  Wholesale     Business           Schinner Inc.
# 3   1100937  9/1/2017     Retail   Individual            Saxon Laviss
# 4   1100938  9/1/2017     Retail     Business  Wilderman Technologies
# 5   1100939  9/2/2017  Wholesale     Business           Turcotte Corp
# 6   1100940  9/2/2017     Retail   Individual        Kovacek Bernhard
# 7   1100941  9/2/2017     Retail   Individual          Antonina Noton
# 8   1100942  9/2/2017     Retail   Individual      Frederik Pantecost
# 9   1100943  9/3/2017  Wholesale     Business      Hettinger and Sons
#
#         CustState     ProdCategory ProdNumber                   ProdName  \
# 0  North Carolina       Blueprints      BP102    Bsquare Robot Blueprint
# 1        Delaware       Drone Kits      DK204                   BYOD-300
# 2         Florida  Training Videos      TV801            Aerial Security
# 3        Virginia       Robot Kits      RK602                  BYOR-1000
# 4           Texas           eBooks      EB502  Building Your First Robot
# 5        New York           Drones      DS302               DC-304 Drone
# 6           Texas  Training Videos      TV803            Cloud Computing
# 7        Missouri           Drones      DS306               DX-145 Drone
# 8       Louisiana           eBooks      EB507  Drone Building Essentials
# 9   West Virginia       Blueprints      BP104        Cat Robot Blueprint
#
#    Quantity   Price  Discount  OrderTotal
# 0        10    8.99       1.8       88.10
# 1         2   89.00       0.0      178.00
# 2        10   36.99       7.4      362.50
# 3         1  189.00       0.0      189.00
# 4         4   24.95       0.0       99.80
# 5        79  395.00      79.0    31126.00
# 6         1   29.99       0.0       29.99
# 7         2  250.00       0.0      500.00
# 8         1   13.99       0.0       13.99
# 9         6    4.99       1.0       28.94

# %% [markdown]
# ## Querying the Data with SQL
#
# We will use the DuckDB library to query the data with native SQL queries using the `sql` function. For example:

# %%
db.sql("DESCRIBE TABLE retail_sales")
# Out:
# ┌──────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │ column_name  │ column_type │  null   │   key   │ default │  extra  │
# │   varchar    │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├──────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ OrderNum     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ OrderDate    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ OrderType    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ CustomerType │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ CustName     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ CustState    │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ ProdCategory │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ ProdNumber   │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ ProdName     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ Quantity     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ Price        │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ Discount     │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# │ OrderTotal   │ DOUBLE      │ YES     │ NULL    │ NULL    │ NULL    │
# ├──────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┤
# │ 13 rows                                                  6 columns │
# └────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Another example, the following query calculate the top 10 states by total sales:

# %%
query = """
SELECT 
  CustState, SUM(OrderTotal) AS Total
FROM 
  retail_sales
GROUP BY 
  CustState
ORDER BY
  Total DESC
LIMIT 10;
"""

# %%
db.sql(query)
# Out:
# ┌────────────────┬────────────────────┐
# │   CustState    │       Total        │
# │    varchar     │       double       │
# ├────────────────┼────────────────────┤
# │ New York       │  616925.8400000001 │
# │ California     │  540285.5199999997 │
# │ Florida        │  394483.7399999998 │
# │ Texas          │ 349925.48000000004 │
# │ North Carolina │  345118.2600000001 │
# │ Pennsylvania   │ 290120.09000000014 │
# │ Minnesota      │ 267308.95000000007 │
# │ Washington     │ 257140.79999999993 │
# │ Virginia       │ 248797.89000000004 │
# │ Georgia        │ 237607.26000000004 │
# ├────────────────┴────────────────────┤
# │ 10 rows                   2 columns │
# └─────────────────────────────────────┘
